# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

df = pd.read_csv('../datasets/Titanic Passengers.csv')
df.shape, df.columns
# Out:
# ((1309, 14),
#  Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#         'fare', 'cabin', 'embarked', 'boat', 'body', 'homedest'],
#        dtype='str'))

# %%
df.head(), df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   name      1309 non-null   str
#  3   sex       1309 non-null   str
#  4   age       1046 non-null   float64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   str
#  8   fare      1308 non-null   float64
#  9   cabin     295 non-null    str
#  10  embarked  1307 non-null   str
#  11  boat      486 non-null    str
#  12  body      121 non-null    float64
#  13  homedest  745 non-null    str
# dtypes: float64(3), int64(4), str(7)
# memory usage: 143.3 KB
# (   pclass  survived                                             name     sex  \
#  0       1         1                    Allen, Miss. Elisabeth Walton  female
# ...

# %%
df['sex'] = df['sex'].map({'female':1, 'male':0})
df['age'] = df['age'].fillna(value=df['age'].mean())
df['first'] = df['pclass'].apply(lambda x:1 if x==1 else 0)
df['business'] = df['pclass'].apply(lambda x:1 if x==2 else 0)
df['economy'] = df['pclass'].apply(lambda x:1 if x==3 else 0)
x = df[['sex', 'age', 'first', 'business', 'economy']]
y = df['survived'] # 1:생존, 0:사망
x.head()
# Out:
#    sex      age  first  business  economy
# 0    1  29.0000      1         0        0
# 1    0   0.9167      1         0        0
# 2    1   2.0000      1         0        0
# 3    0  30.0000      1         0        0
# 4    1  25.0000      1         0        0

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)
model=LogisticRegression( )
model.fit(x_train, y_train)
print('기울기', model.coef_)
print('y절편', model.intercept_)
print('테스트:', model.score(x_test, y_test))
print('학습:', model.score(x_test, y_test))
# Out:
# 기울기 [[ 2.48291701 -0.03712656  1.08246606 -0.11649479 -1.03967208]]
# y절편 [-0.07548099]
# 테스트: 0.7900763358778626
# 학습: 0.7900763358778626

# %%
Jack = np.array([0.0, 20.0, 0, 0, 1])
Rose = np.array([1.0, 17.0, 1, 0, 0])
Nick = np.array([0.0, 70.0, 0, 0, 1])
sample = model.predict([Jack, Rose, Nick])
print('sample', sample)
print(model.predict_proba([Jack, Rose, Nick]))
# Out:
# sample [0 1 0]
# [[0.86502679 0.13497321]
#  [0.05423074 0.94576926]
#  [0.9762007  0.0237993 ]]
# C:\Users\301-23\anaconda3\envs\bio1\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\301-23\anaconda3\envs\bio1\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
