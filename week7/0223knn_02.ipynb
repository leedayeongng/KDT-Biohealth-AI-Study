# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
#와인 데이터
wine = datasets.load_wine()
x = wine.data
y = wine.target
target_nm = wine.target_names
feature_nm = wine.feature_names
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
#스케일링 전 측정
knn_unscaled = KNeighborsClassifier(n_neighbors=5)
knn_unscaled.fit(x_train, y_train)
print(f'[스케일링 전] knn 정확도(k=5):{knn_unscaled.score(x_test, y_test)}')
df = pd.DataFrame(x, columns=feature_nm)
display(df.describe())
# 스케일링: 서로 다른 변수(Feature)들의 값의 범위(단위)를 일정하게 맞추는 작업  --> 스케일링 작업을 하면 knn작업도가 매우 향상된다.
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
knn_scaled = KNeighborsClassifier(n_neighbors=5)
knn_scaled.fit(x_train_scaled, y_train)
print(f'[스케일링 후] knn 정확도 (k=5): : {knn_scaled.score(x_test_scaled, y_test)}')
# Out:
# [스케일링 전] knn 정확도(k=5):0.7222222222222222
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# ...
